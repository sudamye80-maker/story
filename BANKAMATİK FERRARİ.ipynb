# %%
class Bankahesabı():
    def__init__ (self, hesap no, hesap_sahibi, başlangıç bakiyesi)
    self.hesap_no = hesap no
    self.hesap_sahibi = hesap sahibi
    self.bakiye = baslangıc_bakiye
    self.islem_gecmisi = []
    print(f"Hesap Açıldı : {hesap_sahibi} ({hesap_no})")
if baslangıc_bakiye >0 :
    self.islem_gecmisi.append(f"hesap acıldı +{baslangıc_bakiye} TL")
def bakiye_sorgulama(self):
    print(f"{self.hesap_sahibi} bakiyesi: {self.bakiye} TL")
    return self.bakiye
def para_yatırma(self):
    if miktar > 0 :
        self.bakiye += miktar
        self.islem_gecmisi.append(f"paray atırma islem:{miktar} TL Bakiye: {self bakiye} TL")
        print(f"miktar} TL yatırıldı.  Güncel Bakiye: {self bakiye}")

    else
        print(f"gecersiz miktar:{mktar}
              def para_cek(self.miktar):
              if miktar >0
              if self.banka >= miktar
              self.bakiye -= miktar
              self.islem_gecmisi.append(f"(miktar) TL çekildi. ")
              print(f"{miktar} TL para cekildi. Mevcut Bakiye: {self bakiye}")
    else
            print(f"Bakiyeniz Yetersiz!!! istenilen {miktar}, bakiye {self.bakiye}")
def havale_gönder (self,alıcı hesap,miktar):
def havale_gönder (self,alıcı hesap,miktar):
    if öiktar >0 :
    if self.bakiye >= miktar
        self.bakiye -=
        alıcı hesap.bakiye += miktar
        self.ıslem_gecmisi.append(f"Havale gönderildi: {miktar} TL --> {alıcı hesap}")
        alıcı_hesap.islem_gecmisi.append(f" Gönderilen Para: {miktar} TL <--{self.hesap_sahibi}")
        print(f"Havale gönderildi : {miktar} TL")
        print(f" Gönderilen {self.hesap_sahibi} - miktar{miktar}, mevcut Bakiye{Alıcı_hesap.bakiye} TL")
    else
            print(f"yetersiz Bakiye:{self bakiye}")
    else
            prpnt("Gecesiz miktar!!!")
   def islem gecmisi(self)
        print(f"{self.hesap_sahibi}- islem gecmisi")
        print(f"Hesap No: {altı.hesap_no}")
        print(f" Bakiye: {self.bakiye}") 
        print(f"islem sayısı: {len(self.islem_gecmisi)}")
        print{"İSLEMLER"}    
        for i, islem in enumarate(self.islem_gecmisi,1)):   
        print(f"{:} islem {islem5}")
        hesap1 = Banka hesabı("TR001", "Ali Yılmaz", 5000)
        hesap2 =Banka hesabı("TR002", Ayşe Demir", 3000)
        hesap3 = Banka Hesabı("TR003", "Mehmet Örs")
        hesap 3. bakiye sorgula()
        hesap1.para_yatır(2000)
        hesap2.para yatır(1500)
        hesap1.para_cek(2000)
        hesap1.havale_gönder(hesap2,1500)
# Out:
#   Cell In[3], line 2
#     def__init__ (self, hesap no, hesap_sahibi, başlangıç bakiyesi)
#                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
class Araç():
""" parent class = Temel araç"""
def__int__(self, marka, model, yıl)
self.marka = marka
self.model = self.yıl = yıl
self.yakıt = 50
print(f"Araç oluşturuldu": {marka} {model})
def yakıt_doldur(self):
    self.yakıt += litre
    print()
def sur(self,km)
    yakıt_tüketimi = km *0,1
    self.yakıt -= yakıt_tüketimi
    print(f" {km} km sürüldü.Kalan yakıt: {self.yakıt} L")
    Else
    print(f" yetersiz yakıt ! {km} icin{yakıt_tüketimi} L. yakıt gerekli!")
def bilgi(self)
    return (f"{self.marka} {self.model} (self.yıl)-Yakıt {self.yakıt} L")
def ses(self):
    return"vırr vırr"
class spor araba():
def__init__(self, marka, model, yıl, max hız)
super()_init_(marka,model,yıl)self.max_hız = max_hız
self.turbo_modu = True
print(f"spor araba  özelliği eklendi: max hız: {max_hız}km/h")
def sur(self,km):
""" spor araba sürülüyor parent geliştir"""
print (f" spor model aktf")
super().sur(km)
if km >100
print(f" Yüksek hız ! Turbo devrede")
def turbo.ac(self).
self.turbo = true
print("Turbo modu açılsı max hız + 50!")
def turbo_kapat(self)
self.turbo_modu = False
print("Turbo modu kapatıldı.")
def ses(self)  
if self.turbo modu:
    prprint("vrooom vrooom")
    else
    print("vroom vroom")
    def bilgi(self)
    """ spor araba bilgisi - para + ekstra"""
    parent_bilgi = super().bilgi() 
    turbo_durum = "Turbo ON" "if self.turbo max"
    else "Turbo OFF"
    return f"{parent_bilgi} max = {self.max_hız} Km/h {turbo_durum})"
araba = Araç("tyota", "corolla",2020)
print(araba.bilgi())
Araç oluşturdu: Toyota Corolla
Toyota corolla(2020) - Yakıt:50 L
Araba.yakıt_doldur(20)
20 yakıt eklendi.Toplam yakıt:70
araba.sur(65)
65 km sürüldü. Kalan yakıt = 55,5
araba.sur(70)
yetersiz yakıt! 700 km için 700 l yakıt gerekli
araba.ses()
"vırr vırr"
ferrari = spor araba("ferrari", 'F40', 2023, 320)
# Out:
#   Cell In[7], line 2
#     """ parent class = Temel araç"""
#     ^
# IndentationError: expected an indented block after class definition on line 1
